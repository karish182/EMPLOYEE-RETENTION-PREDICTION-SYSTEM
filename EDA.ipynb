# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create dataframe to read csv
df=pd.read_csv("hr_employee_churn_data.csv")

# %%
#check the dataframe and its data
df
# Out:
#        empid  satisfaction_level  last_evaluation  number_project  \
# 0          1                0.38             0.53               2
# 1          2                0.80             0.86               5
# 2          3                0.11             0.88               7
# 3          4                0.72             0.87               5
# 4          5                0.37             0.52               2
# ...      ...                 ...              ...             ...
# 14994  14995                0.40             0.57               2
# 14995  14996                0.37             0.48               2
# 14996  14997                0.37             0.53               2
# 14997  14998                0.11             0.96               6
# 14998  14999                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                       157                   3              0
# ...

# %%
#show first 5 rows
df.head()
# Out:
#    empid  satisfaction_level  last_evaluation  number_project  \
# 0      1                0.38             0.53               2
# 1      2                0.80             0.86               5
# 2      3                0.11             0.88               7
# 3      4                0.72             0.87               5
# 4      5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  salary  left
# 0                      0     low     1
# 1                      0  medium     1
# 2                      0  medium     1
# 3                      0     low     1
# ...

# %%
#see dataframe structure like columns and its datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   empid                  14999 non-null  int64
#  1   satisfaction_level     14997 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  int64
#  4   average_montly_hours   14999 non-null  int64
#  5   time_spend_company     14999 non-null  int64
#  6   Work_accident          14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   salary                 14999 non-null  object
#  9   left                   14999 non-null  int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 1.1+ MB

# %%
#number of rows and columns
df.shape
# Out:
# (14999, 10)

# %%
#describe number columns
df.describe()
# Out:
#               empid  satisfaction_level  last_evaluation  number_project  \
# count  14999.000000        14997.000000     14999.000000    14999.000000
# mean    7500.000000            0.612863         0.716102        3.803054
# std     4329.982679            0.248634         0.171169        1.232592
# min        1.000000            0.090000         0.360000        2.000000
# 25%     3750.500000            0.440000         0.560000        3.000000
# 50%     7500.000000            0.640000         0.720000        4.000000
# 75%    11249.500000            0.820000         0.870000        5.000000
# max    14999.000000            1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# ...

# %%
#some of the columns may have numerical values but actually a categorical column for example we can check the above describe data
#where work_accident is 0 or 1
#and promotion_last_5years is 0 or 1
#and left is 0 or 1

# %%
#use unique function to get unique values
df["Work_accident"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["promotion_last_5years"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#to be used as output value
df["left"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#check total employee range based on target column-left
df["left"].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %%
#using countplot to visualize the above
sns.countplot(x="left",data=df)
plt.show()

# %%
#from the above plot we can see that in training dataset,
#11428 employees left and 3571 employees stayed
#takeaway-less employees left more employees stayed
#i seems there is a class imbalance(data is imbalanced)

# %%
#check salary based on target column-left
df["salary"].value_counts()
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %%
#using countplot to visualize the above
sns.countplot(x="salary",data=df)
plt.show()

# %%
#from the above plot we can see that in training dataset,
#low salaried employees count is high as compared to medium and high
#takeaway-low salary employees are more which is expected

# %%
#split the left column based on the salary
df.groupby("salary")["left"].value_counts()
# Out:
# salary  left
# high    0       1155
#         1         82
# low     0       5144
#         1       2172
# medium  0       5129
#         1       1317
# Name: count, dtype: int64

# %%
#visualize the above data
sns.countplot(x="salary",hue="left",data=df)
plt.show()

# %%
#cat column 1 -salary and left
#feature left split over the feature salary using catplot
sns.catplot(x="left",col="salary",kind="count",data=df)
plt.show()
# Out:
# C:\Users\karis_h66oqv0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#from the above plot we can see that in training dataset,
#takeaway-low salary people have left more

# %%
#feature promotion_last year count value
df["promotion_last_5years"].value_counts()
# Out:
# promotion_last_5years
# 0    14680
# 1      319
# Name: count, dtype: int64

# %%
#visualize the above
sns.countplot(x="promotion_last_5years",data=df)
plt.show()

# %%
#from the above plot we can see that in training dataset,
#takeaway-no promotion_last_5years employees left more as expected

# %%
#split the left column based on the promotion_last_5years
df.groupby("promotion_last_5years")["left"].value_counts()
# Out:
# promotion_last_5years  left
# 0                      0       11128
#                        1        3552
# 1                      0         300
#                        1          19
# Name: count, dtype: int64

# %%
#visualize the above data
sns.countplot(x="promotion_last_5years",hue="left",data=df)
plt.show()

# %%
#cat column 2 -promotion_last_5years and left
#feature left split over the feature promotion_last_5years using catplot
sns.catplot(x="left",col="promotion_last_5years",kind="count",data=df)
plt.show()
# Out:
# C:\Users\karis_h66oqv0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#from the above plot we can see that in training dataset,
#takeaway-no promotion_last_5years employees left more as expected

# %%
#feature work_accident count value
df["Work_accident"].value_counts()
# Out:
# Work_accident
# 0    12830
# 1     2169
# Name: count, dtype: int64

# %%
#using countplot to visualize the above
sns.countplot(x="Work_accident",data=df)
plt.show()

# %%
#from the above plot we can see that in training dataset,
#take away-have very less employees who have work_accident

# %%
#split the left column based on the Work_accident
df.groupby("Work_accident")["left"].value_counts()
# Out:
# Work_accident  left
# 0              0       9428
#                1       3402
# 1              0       2000
#                1        169
# Name: count, dtype: int64

# %%
#cat column 3 -Work_accident and left
#feature left split over the feature Work_accident using catplot
sns.catplot(x="left",col="Work_accident",kind="count",data=df)
plt.show()
# Out:
# C:\Users\karis_h66oqv0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#from the above plot we can see that in training dataset,
#takeaway-employees with less work_accident have left more
#this feature is less important as compared to other features

# %%
#satisfaction level: plot a univariate distribution of observations
sns.distplot(df["satisfaction_level"])
plt.show()
# Out:
# C:\Users\karis_h66oqv0\AppData\Local\Temp\ipykernel_4424\1837051710.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["satisfaction_level"])

# %%
#takeaway-0.1 has maximum observations
#range from 0.1 to 1.0

# %%
#boxplot to show the distribution with respect to category
sns.boxplot(x="left",y="satisfaction_level",data=df)
plt.show()

# %%
#takeaway-employees with less satisfaction_level have left more
#range from 0.2 to 0.5

# %%
#number_project: plot a univariate distribution of observations
sns.distplot(df["number_project"])
plt.show()
# Out:
# C:\Users\karis_h66oqv0\AppData\Local\Temp\ipykernel_4424\2094264790.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["number_project"])

# %%
#takeaway-number_project has highest count at 4
#and distribution range from 2 to 7

# %%
#boxplot to show the distribution with respect to category
sns.boxplot(x="left",y="number_project",data=df)
plt.show()

# %%
#takeaway-employees with high number_project have left more
#and employees retain when project is range from 3 to 4

# %%
#last_evaluation: plot a univariate distribution of observations
sns.distplot(df["last_evaluation"])
plt.show()
# Out:
# C:\Users\karis_h66oqv0\AppData\Local\Temp\ipykernel_4424\2460168496.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["last_evaluation"])

# %%
#takeaway-distributed from .35 to 1.0 where it has high count of 0.55

# %%
#boxplot to show the distribution with respect to category
sns.boxplot(x="left",y="last_evaluation",data=df)
plt.show()

# %%
#takeaway-has no much impact but employees with high last_evaluation have left more

# %%
#average_montly_hours: plot a univariate distribution of observations
sns.distplot(df["average_montly_hours"])
plt.show()
# Out:
# C:\Users\karis_h66oqv0\AppData\Local\Temp\ipykernel_4424\3808804527.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["average_montly_hours"])

# %%
#takeaway-distributed from 96 to 310
#where it has high count of 150

# %%
#boxplot to show the distribution with respect to category
sns.boxplot(x="left",y="average_montly_hours",data=df)
plt.show()

# %%
#takeaway-employees with high average_montly_hours have left more

# %%
#time_spend_company: plot a univariate distribution of observations
sns.distplot(df["time_spend_company"])
plt.show()
# Out:
# C:\Users\karis_h66oqv0\AppData\Local\Temp\ipykernel_4424\3277328509.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["time_spend_company"])

# %%
#takeaway-distributed from 2 to 10
#where it has high count at 3 ad low count at 9

# %%
#boxplot to show the distribution with respect to category
sns.boxplot(x="left",y="time_spend_company",data=df)
plt.show()

# %%
#takeaway-employees with high time_spend_company have left more
#and employees retain when time_spend_company is range from 2 to 3

# %%
#correlation without salary feature(object type)

# Select only numeric columns for correlation
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
df_numeric = df[numeric_columns]

# Compute the correlation matrix
corr = df_numeric.corr()

# Plot the heatmap
sns.heatmap(corr, annot=True)
plt.title('Correlation Heatmap without Salary Feature')
plt.show()

# %%
#checking the pairplot
sns.pairplot(df)
plt.show()
# Out:
# C:\Users\karis_h66oqv0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#completed the exploratory data analysis.
